# %%
import numpy as np
#加载图片 使用matplotlib
import matplotlib.pyplot as plt
#jupyter的魔法指令，预加载，显示图片
# %matplotlib inline
#处理图片 pillow

# %%
nd = np.array([[1,3,5,7,9],[-2,-4,-6,-8,-10],[2,4,6,8,10]])
nd
# Out:
# array([[  1,   3,   5,   7,   9],
#        [ -2,  -4,  -6,  -8, -10],
#        [  2,   4,   6,   8,  10]])

# %%
# numpy切片操作 左闭右开
nd[0:2]
# Out:
# array([[  1,   3,   5,   7,   9],
#        [ -2,  -4,  -6,  -8, -10]])

# %%
#对列进行切片操作
#列表切片时，先是行，再是列
#切片时，： 左右两边没有索引，意味着保留索引
nd[:,1:4]
# Out:
# array([[ 3,  5,  7],
#        [-4, -6, -8],
#        [ 4,  6,  8]])

# %%
img = plt.imread('./flower.jpg')
img
# Out:
# array([[[ 82, 119,  50],
#         [ 80, 117,  48],
#         [ 80, 115,  47],
#         ...,
#         [136, 137, 139],
#         [135, 136, 138],
#         [135, 136, 138]],
#
#        [[ 81, 118,  49],
#         [ 80, 117,  48],
#         [ 79, 114,  46],
#         ...,
#         [135, 136, 140],
#         [134, 135, 137],
#         [134, 135, 137]],
#
#        [[ 80, 117,  48],
#         [ 80, 115,  47],
#         [ 80, 115,  47],
#         ...,
#         [134, 133, 138],
#         [133, 132, 137],
#         [133, 132, 137]],
#
#        ...,
#
#        [[ 39,  60,  43],
#         [ 40,  61,  44],
#         [ 41,  62,  45],
#         ...,
#         [ 47,  62,  19],
#         [ 39,  56,  14],
#         [ 32,  48,   9]],
#
#        [[ 39,  60,  43],
#         [ 40,  61,  44],
#         [ 41,  62,  45],
#         ...,
#         [ 47,  62,  19],
#         [ 38,  55,  13],
#         [ 31,  48,   6]],
#
#        [[ 39,  60,  43],
#         [ 40,  61,  44],
#         [ 41,  62,  45],
# ...

# %%
plt.imshow(img)

# %%
#截取部分图片
img2 = img[0:300,200:500]
plt.imshow(img2)

# %%
img3 = img[280:520,320:640]
plt.imshow(img3)

# %%
# 查看各维度
img.shape
# Out:
# (683, 1024, 3)

# %%
nd[::2]
# Out:
# array([[ 1,  3,  5,  7,  9],
#        [ 2,  4,  6,  8, 10]])

# %%
nd[:,::3]
# Out:
# array([[ 1,  7],
#        [-2, -8],
#        [ 2,  8]])

# %%
nd[:,2::2]
# Out:
# array([[  5,   9],
#        [ -6, -10],
#        [  6,  10]])

# %%
img4 = img[::-1,::-1,[2,1,0]]
plt.imshow(img4)
