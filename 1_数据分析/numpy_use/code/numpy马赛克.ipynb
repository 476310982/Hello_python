# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#切片，从图片中选取一部分
#从数据中，每隔几个取出数据
#对图片而言，如果间隔够大， 显示马赛克效果

# %%
rose = plt.imread('../source/rose.jpg')
plt.imshow(rose)

# %%
rose.shape
# Out:
# (300, 514, 3)

# %%
rose2 = rose[::10,::10]
plt.imshow(rose2)

# %%
rose2.shape
# Out:
# (30, 52, 3)

# %%
tmp = rose[30:170:5,200:330:5]
tmp.shape
# plt.imshow(tmp)
# Out:
# (28, 26, 3)

# %%
rose_2 = rose.copy()
for i in range(28):
    for j in range(26):
        rose_2[30 + i*5:35 + i*5,200 + j*5:205 + j*5]=tmp[i,j]
plt.imshow(rose_2)
