# %%
import numpy as np

import pandas as pd
from pandas import Series,DataFrame

# %%
# 上一讲，append，concat数据集成方法
# merge融合，根据某一共同属性进行级联，高级用法

# %%
df1 = DataFrame({'name':['A','B','C','D','E','F'],
                 'sex':['男','女','女','女','男','男'],
                 'id':[1,2,3,4,5,6]})
df1
# Out:
#   name sex  id
# 0    A   男   1
# 1    B   女   2
# 2    C   女   3
# 3    D   女   4
# 4    E   男   5
# 5    F   男   6

# %%
df2 = DataFrame({'age':[22,25,27,21,18,29],'salary':[12000,15000,20000,30000,10000,8000],'id':[1,2,3,4,5,7]})
df2
# Out:
#    age  salary  id
# 0   22   12000   1
# 1   25   15000   2
# 2   27   20000   3
# 3   21   30000   4
# 4   18   10000   5
# 5   29    8000   7

# %%
df1.append(df2)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#     age  id name   salary  sex
# 0   NaN   1    A      NaN    男
# 1   NaN   2    B      NaN    女
# 2   NaN   3    C      NaN    女
# 3   NaN   4    D      NaN    女
# 4   NaN   5    E      NaN    男
# 5   NaN   6    F      NaN    男
# 0  22.0   1  NaN  12000.0  NaN
# 1  25.0   2  NaN  15000.0  NaN
# 2  27.0   3  NaN  20000.0  NaN
# 3  21.0   4  NaN  30000.0  NaN
# 4  18.0   5  NaN  10000.0  NaN
# 5  29.0   7  NaN   8000.0  NaN

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#   name sex  id  age  salary  id
# 0    A   男   1   22   12000   1
# 1    B   女   2   25   15000   2
# 2    C   女   3   27   20000   3
# 3    D   女   4   21   30000   4
# 4    E   男   5   18   10000   5
# 5    F   男   6   29    8000   7

# %%
df1.merge(df2)
# Out:
#   name sex  id  age  salary
# 0    A   男   1   22   12000
# 1    B   女   2   25   15000
# 2    C   女   3   27   20000
# 3    D   女   4   21   30000
# 4    E   男   5   18   10000

# %%
df1.merge(df2,how = 'outer')
# Out:
#   name  sex  id   age   salary
# 0    A    男   1  22.0  12000.0
# 1    B    女   2  25.0  15000.0
# 2    C    女   3  27.0  20000.0
# 3    D    女   4  21.0  30000.0
# 4    E    男   5  18.0  10000.0
# 5    F    男   6   NaN      NaN
# 6  NaN  NaN   7  29.0   8000.0

# %%
df = DataFrame(np.random.randint(0,150,size = (6,3)),index = list('ABCDEF'),columns=['Python','Math','En'])
df
# Out:
#    Python  Math   En
# A      53   134   43
# B      78   145   32
# C       3    62   57
# D     135    32   50
# E      63    50   84
# F     120    29  118

# %%
s = df.mean().round(1)
s
# Out:
# Python    75.3
# Math      75.3
# En        64.0
# dtype: float64

# %%
df2 = DataFrame(s)
df2.columns = ['score_mean']
df2
# Out:
#         score_mean
# Python        75.3
# Math          75.3
# En            64.0

# %%
df3 = df2.T
df3
# Out:
#             Python  Math    En
# score_mean    75.3  75.3  64.0

# %%
df4 = df.append(df3)
df4
# Out:
#             Python   Math     En
# A             53.0  134.0   43.0
# B             78.0  145.0   32.0
# C              3.0   62.0   57.0
# D            135.0   32.0   50.0
# E             63.0   50.0   84.0
# F            120.0   29.0  118.0
# score_mean    75.3   75.3   64.0

# %%
df5 = DataFrame(df4.mean(axis = 1).round(1))
df5.columns = ['score_mean']
df5
# Out:
#             score_mean
# A                 76.7
# B                 85.0
# C                 40.7
# D                 72.3
# E                 65.7
# F                 89.0
# score_mean        71.5

# %%
df4.merge(df5,left_index=True,right_index=True)
# Out:
#             Python   Math     En  score_mean
# A             53.0  134.0   43.0        76.7
# B             78.0  145.0   32.0        85.0
# C              3.0   62.0   57.0        40.7
# D            135.0   32.0   50.0        72.3
# E             63.0   50.0   84.0        65.7
# F            120.0   29.0  118.0        89.0
# score_mean    75.3   75.3   64.0        71.5
